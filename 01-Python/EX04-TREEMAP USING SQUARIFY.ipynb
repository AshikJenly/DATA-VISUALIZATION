# %%
import squarify
import matplotlib.pyplot as plt

# %%
cars = ['AUDI', 'BMW', 'FORD','TESLA', 'JAGUAR', 'MERCEDES']
data = [23, 17, 15, 29, 12, 41]
colors= ["red","pink","green","violet","yellow","blue"]

# %% [markdown]
# # Simple Tree

# %%
squarify.plot(data,color=colors)
plt.axis('off')
# Out:
# (0.0, 100.0, 0.0, 100.0)

# %% [markdown]
# # With Axis

# %%
squarify.plot(data,color=colors,label=cars,pad=2)
# Out:
# <Axes: >
