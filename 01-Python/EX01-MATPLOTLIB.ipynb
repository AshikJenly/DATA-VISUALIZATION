# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# # 1) Line Chart

# %%
x1 = np.arange(1,40,2)
y1 = np.random.randint(1,100,20)

x2 = np.arange(10,50,2)
y2 = np.random.randint(1,100,20)

# %%
plt.title("Interesting Graph")
plt.xlabel("Plot Number")
plt.ylabel("Random value")
plt.plot(x1,y1,label="First Line")
plt.plot(x2,y2,label="Second Line")
plt.yticks(np.arange(0,101,20))
plt.legend()

# %% [markdown]
# ### With DataSet

# %%
df = pd.read_csv("./DataSets/salaries.csv")
plt.plot(df["phd"])
plt.plot(df["service"])

# %% [markdown]
# # 2) Bar Chart

# %%
plt.bar(df["sex"],df["phd"])
plt.bar(df["rank"],df["service"])
# Out:
# <BarContainer object of 78 artists>

# %% [markdown]
# # 3) Stacked bar Chart

# %%
x=['A','B','C','D']
y1=np.array([10,20,10,30])
y2=np.array([20,25,15,25])
y3=np.array([12,15,19,6])
y4=np.array([10,29,13,19])

plt.bar(x,y1,color='r')
plt.bar(x,y2,bottom=y1,color='b')
plt.bar(x,y3,bottom=y1+y2,color='y')
plt.bar(x,y4,bottom=y1+y2+y3,color='g')
plt.legend(["Round 1","Round 2","Round 3","Round 4"])

# %% [markdown]
# # 3) Scatter Plot

# %%
plt.scatter(df["phd"],df["salary"],color="g",marker="+",s=50)

# %% [markdown]
# # 4) Pie Chart

# %%
cars = ['AUDI', 'BMW', 'FORD','TESLA', 'JAGUAR', 'MERCEDES']
data = [23, 17, 35, 29, 12, 41]

# %%
fig,ax = plt.subplots(figsize=(7,7))
wedges, texts, autotexts = ax.pie(
    data,
    labels=cars,
    autopct='%1.2f%%',
    labeldistance=1.1,
    startangle=90,
    explode=(0,0,0.2,0,0.1,0),
    shadow=True,
    textprops=dict(color="magenta")
)
ax.legend(
    cars,
    loc="center left",
    bbox_to_anchor =(1,0,0,1)
)
